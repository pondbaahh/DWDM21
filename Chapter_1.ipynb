# %% [markdown]
# <a href="https://colab.research.google.com/github/pondbaahh/DWDM21/blob/main/Chapter_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## สรุป Chapter 1

# %% [markdown]
# Data Mining คือ การทำเหมืองข้อมูล โดยการขุดข้อมูลสกัดข้อมูลเพื่อให้ได้เพชรหรือข้อมูลที่ต้องการออกมา
#
# การวิเคราะห์ข้อมูลจากข้อมูลจำนวนมาก เพื่อหาความสัมพันธ์ของข้อมูลที่ซ่อนอยู่
#                โดยทำการจำแนกประเภท รูปแบบ เชื่อมโยงข้อมูลที่มีความสัมพันธ์กัน
#
# ชื่อแรกก่อนที่ที่จะชื่อ Data Mining คือชื่อ "Knowledge discovery(mining) is databadses(KDD)"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# อธิบายภาพข้างต้น
#
#  ดึงข้อมูลจากฟิลด์มาจากที่ต่างๆ และdata werehouse จะเอาข้อมูลมารวมกันว่าจะดูแบบละเอียดหรือแบบสรุป จากนั้นเลือกมาเฉพาะข้อมูลที่จะมาสกัดองค์ความรู้จริงๆ และมาทำData Mining แล้วก็จะได้รูปแบบที่ซ่อนในข้อมูลหรือ Pattern Evaluation จากนั้นก็วัดผลว่าองค์ความรู้ที่สกัดมาเป็นความรู้จริงๆนะ และสรุปออกมาเป็นองค์ความรู้

# %% [markdown]
# ###ความสำคัญของ Data Mining
#
# สามารถแสดงให้คนอื่นเห็นได้ว่าเราได้ข้อมูลมาเเล้ว และสามารถอธิบายข้อมูลได้

# %% [markdown]
# ### Data Mining in Business Intellinence

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###How the data suppose to look like

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Column : Attributes,คำที่ใช้อธิบายคุณสมบัติของข้อมูล
#
# Rows : Records, ข้อมูลแต่ละตัว

# %% [markdown]
# ###Association Rules กฎความสัมพันธ์
#
# การหาความสัมพันธ์ของข้อมูลสองชุดหรือมากกว่าสองชุดขึ้นไปภายในกลุ่มข้อมูลที่มีขนาดใหญ่

# %% [markdown]
# ###Classification การจำแนกกลุ่ม
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# การเลือก 1 column มาเป็นคำตอบแล้วเอามาทำนายข้อมูลที่เหลือ ซึ่งทำนายแบบไม่เป็นตัวเลข

# %% [markdown]
# ## Cluster Analysis การแบ่งกลุ่ม
#
#  เอาข้อมูลคล้ายๆกันมาอยู่ด้วยกัน
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ไม่มีคำตอบให้ทำนาย แค่เพียงต้องการจัดกลุ่มข้อมูลเฉยๆ
