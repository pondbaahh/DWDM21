# %% [markdown]
# <a href="https://colab.research.google.com/github/pondbaahh/DWDM21/blob/main/Project_SUKUNA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project กลุ่ม
# *  present วันที่ 31 สิงหาคม 2564
# *  ข้อมูลที่ไปดึงมาจาก 3 แหล่ง
# *  แสดงวิธีการโหลด
# *  ความเชื่อมโยงของ 3 ตาราง (index)

# %% [markdown]
# ที่มาของข้อมูล : http://data.bangkok.go.th/dataset/10, http://data.bangkok.go.th/dataset/garbage, http://data.bangkok.go.th/dataset/popmovement และ https://opendata.data.go.th/uk/dataset/district2

# %%
import pandas as pd #ทำงานกับข้อมูลลักษณะตาราง

# %%
from google.colab import drive #เชื่อมเข้ากับ Drive 
drive.mount('/content/drive')  # คลิกที่ลิงก์ -> เลือก E-mail -> ลงชื่อเข้าใช้ -> ก็อปโค้ด -> นำกลับมาวางในช่องว่าง -> กด enter
# Out:
# Mounted at /content/drive

# %%
import os #os เอาไว้จัดการไฟล์และ path

# %%
path = '/content/drive/My Drive/DWDM2021_DATA'

# %%
population = pd.read_csv(os.path.join(path, 'population.csv'))
garbage = pd.read_csv(os.path.join(path, 'garbage.csv'))
moveinmoveout = pd.read_csv(os.path.join(path, 'moveinmoveout.csv'))

# %% [markdown]
# ##**ข้อมูลชุดที่ 1 จำนวนประชากรในกรุงเทพมหานคร**

# %%
population
# Out:
#     dcode  population48  population49  ...  population59  population60  population61
# 0    1001         67357         65835  ...         52522             0         50382
# 1    1002        121336        119927  ...         98450             0         94854
# 2    1003        126126        133415  ...        167844             0        172990
# 3    1004         50023         49730  ...         47308             0         48207
# 4    1005        178986        181390  ...        190828             0        191323
# 5    1006        149093        149860  ...        148392             0        146841
# 6    1007         63192         62102  ...         49594             0         48382
# 7    1008         60001         58768  ...         47450             0         45701
# 8    1009         98564         98096  ...         91305             0         89237
# 9    1010        118019        122825  ...        141214             0        142311
# ...

# %% [markdown]
# **dcode = PK ของตาราง คือเขตภายในกรุงเทพมหานคร**
#
# **population48 = จำนวนประชากรในปี 2548**
#
# **population48 = จำนวนประชากรในปี 2549  เป็นต้น**

# %% [markdown]
# ##**ข้อมูลชุดที่ 2 จำนวนขยะในเขตกรุงเทพมหานคร**

# %%
garbage
# Out:
#     dcode  garbage53  ...  garbage61  garbageperday61
# 0    1000  189819.45  ...  219418.80           601.15
# 1    1001   69166.29  ...   71372.82           195.54
# 2    1002   62244.26  ...   62186.37           170.37
# 3    1003   32339.16  ...   50319.74           137.86
# 4    1004   54224.38  ...   56632.20           155.16
# 5    1005   85742.96  ...  112955.13           309.47
# 6    1006  101745.01  ...  124970.88           342.39
# 7    1007   75719.25  ...  111800.66           306.30
# 8    1008   32203.77  ...   29790.81            81.62
# 9    1009   48978.52  ...   53164.78           145.66
# 10   1010   60341.96  ...   69576.22           190.62
# 11   1011   71764.46  ...  109139.10           299.01
# 12   1012   58392.59  ...   68049.42           186.44
# 13   1013   21238.74  ...   19879.55            54.46
# 14   1014   54181.74  ...   64478.78           176.65
# 15   1015   60352.95  ...   59648.60           163.42
# ...

# %% [markdown]
# **dcode = PK ของตาราง คือเขตภายในกรุงเทพมหานคร**
#
# **garbage53 = ปริมาณขยะของกรุงเทพในปี 2553**
#
# **garbageperday53 = ปริมาณขยะของกรุงเทพต่อวันในปี 2553  เป็นต้น**

# %% [markdown]
# ##**ข้อมูลชุดที่ 3 จำนวนคนย้ายเข้า-ย้ายออกในกรุงเทพมหานคร**

# %%
moveinmoveout
# Out:
#     dcode  movein52  movein53  ...  moveout59  moveout60  moveout61
# 0    1045      8406      7353  ...       7174       9393       9935
# 1    1035      9116      8257  ...       7891       9072       9141
# 2    1049      8941      8203  ...       6083       4329       3948
# 3    1002      7534      7352  ...      13091       4878       4750
# 4    1038      9535      8939  ...       7467       5486       5415
# 5    1050      8341      8811  ...       5789       8086       7984
# 6    1022      9164      7597  ...       8452       5800       5686
# 7    1027     11546      9854  ...       8462       6069       7000
# 8    1006     11369      9980  ...       9826       3518       3503
# 9    1010     11085     10224  ...      12231       8724       8300
# 10   1030     11871      9604  ...      10502      11802      12206
# 11   1040     12286     11375  ...      10126      14151      13804
# 12   1003     11544     11400  ...       7536       3330       3373
# ...

# %% [markdown]
# **dcode = PK ของตาราง คือเขตภายในกรุงเทพมหานคร**
#
# **movein52 = จำนวนคนที่ย้ายเข้ากรุงเทพในปี 2552**
#
# **moveout52 = จำนวนคนที่ย้ายออกจากกรุงเทพในปี 2552  เป็นต้น**

# %% [markdown]
# ###**เรียง dcode ใหม่ ให้เป็นไปตามลำดับ**

# %%
moveinmoveout_new = moveinmoveout.sort_values(by=['dcode'],ascending=True)
moveinmoveout_new
# Out:
#     dcode  movein52  movein53  ...  moveout59  moveout60  moveout61
# 45   1001      3461      2965  ...       3644      10292      11239
# 3    1002      7534      7352  ...      13091       4878       4750
# 12   1003     11544     11400  ...       7536       3330       3373
# 47   1004      1878      1797  ...       5967       5290       5174
# 17   1005     16617     15512  ...      13537       4914       4890
# 8    1006     11369      9980  ...       9826       3518       3503
# 46   1007      2753      2880  ...       8863       8230       8308
# 48   1008      1797      1587  ...       3340       6400       6252
# 35   1009      5941      5243  ...       5796       7096       6820
# 9    1010     11085     10224  ...      12231       8724       8300
# 16   1011     16392     15118  ...       9343       7116       7026
# 38   1012      4799      4621  ...       4188       7757       7581
# 49   1013      1036       815  ...       1268       4425       4281
# ...

# %% [markdown]
# ## หา Missing Value

# %%
population.isnull().any()
# Out:
# dcode           False
# population48    False
# population49    False
# population50    False
# population51    False
# population52    False
# population53    False
# population54    False
# population55    False
# population56    False
# population57    False
# population58    False
# population59    False
# population60    False
# population61    False
# dtype: bool

# %% [markdown]
# จากการตรวจสอบค่า Missing พบว่า ไม่มีค่าไหนในตารางที่มีช่องว่างเลย

# %%
garbage.isnull().any()
# Out:
# dcode              False
# garbage53          False
# garbageperday53    False
# garbage54          False
# garbageperday54    False
# garbage55          False
# garbageperday55    False
# garbage56          False
# garbageperday56    False
# garbage57          False
# garbageperday57    False
# garbage58          False
# garbageperday58    False
# garbage59          False
# garbageperday59    False
# garbage60          False
# garbageperday60    False
# garbage61          False
# garbageperday61    False
# dtype: bool

# %% [markdown]
# จากการตรวจสอบค่า Missing พบว่า ไม่มีค่าไหนในตารางที่มีช่องว่างเลย

# %%
moveinmoveout.isnull().any()
# Out:
# dcode        False
# movein52     False
# movein53     False
# movein54     False
# movein55     False
# movein56     False
# movein57     False
# movein58     False
# movein59     False
# movein60     False
# movein61     False
# moveout52    False
# moveout53    False
# moveout54    False
# moveout55    False
# moveout56    False
# moveout57    False
# moveout58    False
# moveout59    False
# moveout60    False
# moveout61    False
# dtype: bool

# %% [markdown]
# จากการตรวจสอบค่า Missing พบว่า ไม่มีค่าไหนในตารางที่มีช่องว่างเลย

# %% [markdown]
# **ตัด coloum population60 ออกเนื่องจากข้อมูลมีค่าเป็น 0 นั่นคือ ข้อมูลไม่เป็นความจริง**

# %%
population.drop(['population60'], axis=1, inplace=True)

# %%
population
# Out:
#     dcode  population48  population49  ...  population58  population59  population61
# 0    1001         67357         65835  ...         54195         52522         50382
# 1    1002        121336        119927  ...        103230         98450         94854
# 2    1003        126126        133415  ...        164494        167844        172990
# 3    1004         50023         49730  ...         46606         47308         48207
# 4    1005        178986        181390  ...        190528        190828        191323
# 5    1006        149093        149860  ...        149070        148392        146841
# 6    1007         63192         62102  ...         50852         49594         48382
# 7    1008         60001         58768  ...         48615         47450         45701
# 8    1009         98564         98096  ...         92206         91305         89237
# 9    1010        118019        122825  ...        140335        141214        142311
# ...

# %% [markdown]
# **ตัด coloumn ตั้งแต่ปี 48-52 ออก เพราะต้องการตั้งแต่ปี 53**

# %%
population.drop(['population48', 'population49', 'population50' ,'population51' ,'population52'], axis=1, inplace=True)

# %%
population
# Out:
#     dcode  population53  population54  ...  population58  population59  population61
# 0    1001         60313         58771  ...         54195         52522         50382
# 1    1002        111496        108815  ...        103230         98450         94854
# 2    1003        151292        154371  ...        164494        167844        172990
# 3    1004         47053         46087  ...         46606         47308         48207
# 4    1005        188164        188252  ...        190528        190828        191323
# 5    1006        149606        148645  ...        149070        148392        146841
# 6    1007         57368         54996  ...         50852         49594         48382
# 7    1008         53526         52093  ...         48615         47450         45701
# 8    1009         95661         94482  ...         92206         91305         89237
# 9    1010        135032        136236  ...        140335        141214        142311
# ...

# %% [markdown]
# **ตัด coloum ของปี 60 ออกทั้งตาราง garbage และ moveinmoveout**

# %%
garbage.drop(['garbage60','garbageperday60'], axis=1, inplace=True)

# %%
garbage
# Out:
#     dcode  garbage53  ...  garbage61  garbageperday61
# 0    1000  189819.45  ...  219418.80           601.15
# 1    1001   69166.29  ...   71372.82           195.54
# 2    1002   62244.26  ...   62186.37           170.37
# 3    1003   32339.16  ...   50319.74           137.86
# 4    1004   54224.38  ...   56632.20           155.16
# 5    1005   85742.96  ...  112955.13           309.47
# 6    1006  101745.01  ...  124970.88           342.39
# 7    1007   75719.25  ...  111800.66           306.30
# 8    1008   32203.77  ...   29790.81            81.62
# 9    1009   48978.52  ...   53164.78           145.66
# 10   1010   60341.96  ...   69576.22           190.62
# 11   1011   71764.46  ...  109139.10           299.01
# 12   1012   58392.59  ...   68049.42           186.44
# 13   1013   21238.74  ...   19879.55            54.46
# 14   1014   54181.74  ...   64478.78           176.65
# 15   1015   60352.95  ...   59648.60           163.42
# ...

# %%
moveinmoveout_new.drop(['movein60','moveout60'], axis=1, inplace=True)

# %%
moveinmoveout_new
# Out:
#     dcode  movein52  movein53  ...  moveout58  moveout59  moveout61
# 45   1001      3461      2965  ...       3589       3644      11239
# 3    1002      7534      7352  ...      11133      13091       4750
# 12   1003     11544     11400  ...       7611       7536       3373
# 47   1004      1878      1797  ...       5948       5967       5174
# 17   1005     16617     15512  ...      12299      13537       4890
# 8    1006     11369      9980  ...       9549       9826       3503
# 46   1007      2753      2880  ...       9502       8863       8308
# 48   1008      1797      1587  ...       3615       3340       6252
# 35   1009      5941      5243  ...       4846       5796       6820
# 9    1010     11085     10224  ...      12268      12231       8300
# 16   1011     16392     15118  ...       9167       9343       7026
# 38   1012      4799      4621  ...       4161       4188       7581
# 49   1013      1036       815  ...       1083       1268       4281
# ...

# %% [markdown]
# **ตัด coloumn ปี 52 ออก เพราะต้องการตั้งแต่ปี 53**

# %%
moveinmoveout_new.drop(['movein52','moveout52'], axis=1, inplace=True)

# %%
moveinmoveout_new
# Out:
#     dcode  movein53  movein54  ...  moveout58  moveout59  moveout61
# 45   1001      2965      2892  ...       3589       3644      11239
# 3    1002      7352      7890  ...      11133      13091       4750
# 12   1003     11400     11730  ...       7611       7536       3373
# 47   1004      1797      1626  ...       5948       5967       5174
# 17   1005     15512     14312  ...      12299      13537       4890
# 8    1006      9980      9547  ...       9549       9826       3503
# 46   1007      2880      2245  ...       9502       8863       8308
# 48   1008      1587      1441  ...       3615       3340       6252
# 35   1009      5243      5034  ...       4846       5796       6820
# 9    1010     10224      9786  ...      12268      12231       8300
# 16   1011     15118     14147  ...       9167       9343       7026
# 38   1012      4621      4300  ...       4161       4188       7581
# 49   1013       815       753  ...       1083       1268       4281
# ...

# %% [markdown]
# **ในตาราง garbage ตัด colounm garbageperday ของทุกปีออก เนื่องจากต้องการทราบเฉพาะปริมาณรวมขยะของแต่ละปี**

# %%
garbage.drop(['garbageperday53','garbageperday54','garbageperday55','garbageperday56','garbageperday57','garbageperday58','garbageperday59','garbageperday61'], axis=1, inplace=True)

# %%
garbage
# Out:
#     dcode  garbage53  garbage54  ...  garbage58  garbage59  garbage61
# 0    1000  189819.45  122869.76  ...  217247.09  199522.73  219418.80
# 1    1001   69166.29  106149.08  ...   72019.02   70243.12   71372.82
# 2    1002   62244.26  105379.61  ...   63580.71   63750.08   62186.37
# 3    1003   32339.16   95059.04  ...   43111.42   43545.74   50319.74
# 4    1004   54224.38   94655.76  ...   61746.75   58286.80   56632.20
# 5    1005   85742.96   87370.03  ...   99176.79  102066.16  112955.13
# 6    1006  101745.01   87276.00  ...  113420.03  106544.60  124970.88
# 7    1007   75719.25   86006.01  ...  104085.17   30383.52  111800.66
# 8    1008   32203.77   82532.46  ...   31207.79  117706.24   29790.81
# 9    1009   48978.52   78200.31  ...   54404.30   53592.83   53164.78
# 10   1010   60341.96   75249.90  ...   69591.76   69050.94   69576.22
# 11   1011   71764.46   73467.95  ...   93967.27   95759.88  109139.10
# ...

# %% [markdown]
# ##**รวมตาราง 2 ตารางเข้าด้วยกัน โดยให้ตาราง population เป็นตารางหลัก**

# %%
merged_table = population.merge(garbage,how='left',left_on='dcode',right_on='dcode') #แบบอาจารย์
merged_table
# Out:
#     dcode  population53  population54  ...  garbage58  garbage59  garbage61
# 0    1001         60313         58771  ...   72019.02   70243.12   71372.82
# 1    1002        111496        108815  ...   63580.71   63750.08   62186.37
# 2    1003        151292        154371  ...   43111.42   43545.74   50319.74
# 3    1004         47053         46087  ...   61746.75   58286.80   56632.20
# 4    1005        188164        188252  ...   99176.79  102066.16  112955.13
# 5    1006        149606        148645  ...  113420.03  106544.60  124970.88
# 6    1007         57368         54996  ...  104085.17   30383.52  111800.66
# 7    1008         53526         52093  ...   31207.79  117706.24   29790.81
# 8    1009         95661         94482  ...   54404.30   53592.83   53164.78
# 9    1010        135032        136236  ...   69591.76   69050.94   69576.22
# 10   1011        157477        160850  ...   93967.27   95759.88  109139.10
# ...

# %%
tablepop_garbage = pd.merge(population, garbage,how='left', on='dcode') #ใช้ on เนื่องจากตารางทั้งสองมีตำแหน่งคอลัมน์ร่วมกันซึ่งใช้เป็นคีย์ในการรวมข้อมูล (dcode)
tablepop_garbage
# Out:
#     dcode  population53  population54  ...  garbage58  garbage59  garbage61
# 0    1001         60313         58771  ...   72019.02   70243.12   71372.82
# 1    1002        111496        108815  ...   63580.71   63750.08   62186.37
# 2    1003        151292        154371  ...   43111.42   43545.74   50319.74
# 3    1004         47053         46087  ...   61746.75   58286.80   56632.20
# 4    1005        188164        188252  ...   99176.79  102066.16  112955.13
# 5    1006        149606        148645  ...  113420.03  106544.60  124970.88
# 6    1007         57368         54996  ...  104085.17   30383.52  111800.66
# 7    1008         53526         52093  ...   31207.79  117706.24   29790.81
# 8    1009         95661         94482  ...   54404.30   53592.83   53164.78
# 9    1010        135032        136236  ...   69591.76   69050.94   69576.22
# 10   1011        157477        160850  ...   93967.27   95759.88  109139.10
# ...

# %%
tablepop_garb_moveinout = pd.merge(tablepop_garbage, moveinmoveout_new,how='left', on='dcode')

# %%
tablepop_garb_moveinout
# Out:
#     dcode  population53  population54  ...  moveout58  moveout59  moveout61
# 0    1001         60313         58771  ...       3589       3644      11239
# 1    1002        111496        108815  ...      11133      13091       4750
# 2    1003        151292        154371  ...       7611       7536       3373
# 3    1004         47053         46087  ...       5948       5967       5174
# 4    1005        188164        188252  ...      12299      13537       4890
# 5    1006        149606        148645  ...       9549       9826       3503
# 6    1007         57368         54996  ...       9502       8863       8308
# 7    1008         53526         52093  ...       3615       3340       6252
# 8    1009         95661         94482  ...       4846       5796       6820
# 9    1010        135032        136236  ...      12268      12231       8300
# 10   1011        157477        160850  ...       9167       9343       7026
# ...

# %% [markdown]
# เขตไหนที่มีขยะมากที่สุด ในปี 61 จากตาราง tablepop_garb_moveinout

# %%
MaxGar61 = tablepop_garb_moveinout.sort_values(by=['garbage61'],ascending=False)
MaxGar61.iloc[:1,[0,16]]
# Out:
#     dcode  garbage61
# 29   1030   157389.2

# %% [markdown]
# เขตไหนที่มีขยะน้อยที่สุด ในปี 61 จากตาราง tablepop_garb_moveinout

# %%
MinGar61 = tablepop_garb_moveinout.sort_values(by=['garbage61'],ascending=True)
MinGar61.iloc[:1,[0,16]]
# Out:
#     dcode  garbage61
# 12   1013   19879.55

# %% [markdown]
# ##**เพิ่มเติม - เพิ่มชื่อเขตแต่ละเขตว่าชื่ออะไรบ้าง และหาค่าที่หายไป**

# %%
district = pd.read_csv(os.path.join(path, 'district.csv'))

# %% [markdown]
# ### **ตารางชื่อเขตภายในกรุงเทพมหานคร**

# %%
district
# Out:
#     dcode              dname
# 0    1001             พระนคร
# 1    1002              ดุสิต
# 2    1003            หนองจอก
# 3    1004             บางรัก
# 4    1005             บางเขน
# 5    1006            บางกะปิ
# 6    1007            ปทุมวัน
# 7    1008  ป้อมปราบศัตรูพ่าย
# 8    1009            พระโขนง
# 9    1010            มีนบุรี
# 10   1011          ลาดกระบัง
# 11   1012            ยานนาวา
# 12   1013        สัมพันธวงศ์
# 13   1014              พญาไท
# 14   1015             ธนบุรี
# 15   1016         บางกอกใหญ่
# 16   1017           ห้วยขวาง
# 17   1018            คลองสาน
# 18   1019           ตลิ่งชัน
# 19   1020         บางกอกน้อย
# 20   1021        บางขุนเทียน
# 21   1022          ภาษีเจริญ
# 22   1023            หนองแขม
# 23   1024        ราษฎร์บูรณะ
# 24   1025            บางพลัด
# 25   1026             ดินแดง
# 26   1027            บึงกุ่ม
# 27   1028               สาทร
# 28   1029            บางซื่อ
# 29   1030            จตุจักร
# 30   1031          บางคอแหลม
# ...

# %% [markdown]
# **dcode = PK ของตาราง คือรหัสเขตภายในกรุงเทพมหานคร**
#
# **dname = FK ของตาราง คือชื่อเขตภายในกรุงเทพมหานคร**

# %%
garbage
# Out:
#     dcode  garbage53  garbage54  ...  garbage58  garbage59  garbage61
# 0    1000  189819.45  122869.76  ...  217247.09  199522.73  219418.80
# 1    1001   69166.29  106149.08  ...   72019.02   70243.12   71372.82
# 2    1002   62244.26  105379.61  ...   63580.71   63750.08   62186.37
# 3    1003   32339.16   95059.04  ...   43111.42   43545.74   50319.74
# 4    1004   54224.38   94655.76  ...   61746.75   58286.80   56632.20
# 5    1005   85742.96   87370.03  ...   99176.79  102066.16  112955.13
# 6    1006  101745.01   87276.00  ...  113420.03  106544.60  124970.88
# 7    1007   75719.25   86006.01  ...  104085.17   30383.52  111800.66
# 8    1008   32203.77   82532.46  ...   31207.79  117706.24   29790.81
# 9    1009   48978.52   78200.31  ...   54404.30   53592.83   53164.78
# 10   1010   60341.96   75249.90  ...   69591.76   69050.94   69576.22
# 11   1011   71764.46   73467.95  ...   93967.27   95759.88  109139.10
# ...

# %% [markdown]
# ###จากตาราง garbage จะเห็นได้ว่า dcode เริ่มตั้งแต่ 1000 ซึ่งจากตาราง district ชื่อเขตไม่มี dcode 1000 จึงต้องตัด dcode 1000 ของ garbage ออก

# %%
garbage_new = garbage.drop(0, axis=0)

# %%
garbage_new
# Out:
#     dcode  garbage53  garbage54  ...  garbage58  garbage59  garbage61
# 1    1001   69166.29  106149.08  ...   72019.02   70243.12   71372.82
# 2    1002   62244.26  105379.61  ...   63580.71   63750.08   62186.37
# 3    1003   32339.16   95059.04  ...   43111.42   43545.74   50319.74
# 4    1004   54224.38   94655.76  ...   61746.75   58286.80   56632.20
# 5    1005   85742.96   87370.03  ...   99176.79  102066.16  112955.13
# 6    1006  101745.01   87276.00  ...  113420.03  106544.60  124970.88
# 7    1007   75719.25   86006.01  ...  104085.17   30383.52  111800.66
# 8    1008   32203.77   82532.46  ...   31207.79  117706.24   29790.81
# 9    1009   48978.52   78200.31  ...   54404.30   53592.83   53164.78
# 10   1010   60341.96   75249.90  ...   69591.76   69050.94   69576.22
# 11   1011   71764.46   73467.95  ...   93967.27   95759.88  109139.10
# 12   1012   58392.59   73220.38  ...   67058.97   67770.90   68049.42
# ...

# %% [markdown]
# ##**รวมตารางใหม่ 2 ตารางเข้าด้วยกัน โดยให้ตาราง population เป็นตารางหลัก**

# %%
pop_district = pd.merge(district, population,how='left', on='dcode')
pop_district
# Out:
#     dcode              dname  ...  population59  population61
# 0    1001             พระนคร  ...         52522         50382
# 1    1002              ดุสิต  ...         98450         94854
# 2    1003            หนองจอก  ...        167844        172990
# 3    1004             บางรัก  ...         47308         48207
# 4    1005             บางเขน  ...        190828        191323
# 5    1006            บางกะปิ  ...        148392        146841
# 6    1007            ปทุมวัน  ...         49594         48382
# 7    1008  ป้อมปราบศัตรูพ่าย  ...         47450         45701
# 8    1009            พระโขนง  ...         91305         89237
# 9    1010            มีนบุรี  ...        141214        142311
# 10   1011          ลาดกระบัง  ...        171933        175662
# 11   1012            ยานนาวา  ...         79574         78031
# 12   1013        สัมพันธวงศ์  ...         24785         23655
# 13   1014              พญาไท  ...         72102         70341
# ...

# %% [markdown]
# **dcode = PK ของตาราง คือเขตภายในกรุงเทพมหานคร**
#
# **dname = FK ของตาราง คือชื่อเขตภายในกรุงเทพมหานคร**
#
# **population53 = จำนวนประชากรคนกรุงเทพในปี 2553**
#
# **population54 = จำนวนประชากรคนกรุงเทพในปี 2554  เป็นต้น**

# %% [markdown]
# ### เช็คว่ามีค่า Missing มั้ย

# %%
pop_district.isnull().any()
# Out:
# dcode           False
# dname           False
# population53    False
# population54    False
# population55    False
# population56    False
# population57    False
# population58    False
# population59    False
# population61    False
# dtype: bool

# %% [markdown]
# จากที่เช็คค่า Missing แล้ว ไม่มีค่า Missing เกิดขึ้นหลังจากรวมตารางแล้ว

# %% [markdown]
# ##**รวมตาราง population และ garbage**

# %%
pop_gar = pd.merge(pop_district, garbage_new,how='left', on='dcode')
pop_gar
# Out:
#     dcode              dname  population53  ...  garbage58  garbage59  garbage61
# 0    1001             พระนคร         60313  ...   72019.02   70243.12   71372.82
# 1    1002              ดุสิต        111496  ...   63580.71   63750.08   62186.37
# 2    1003            หนองจอก        151292  ...   43111.42   43545.74   50319.74
# 3    1004             บางรัก         47053  ...   61746.75   58286.80   56632.20
# 4    1005             บางเขน        188164  ...   99176.79  102066.16  112955.13
# 5    1006            บางกะปิ        149606  ...  113420.03  106544.60  124970.88
# 6    1007            ปทุมวัน         57368  ...  104085.17   30383.52  111800.66
# 7    1008  ป้อมปราบศัตรูพ่าย         53526  ...   31207.79  117706.24   29790.81
# 8    1009            พระโขนง         95661  ...   54404.30   53592.83   53164.78
# 9    1010            มีนบุรี        135032  ...   69591.76   69050.94   69576.22
# 10   1011          ลาดกระบัง        157477  ...   93967.27   95759.88  109139.10
# ...

# %% [markdown]
# **dcode = PK ของตาราง คือเขตภายในกรุงเทพมหานคร**
#
# **dname = FK ของตาราง คือชื่อเขตภายในกรุงเทพมหานคร**
#
# **population53 = จำนวนประชากรคนกรุงเทพในปี 2553**
#
# **garbage53 = ปริมาณขยะของกรุงเทพในปี 2553  เป็นต้น**

# %% [markdown]
# ### เช็คว่ามีค่า Missing มั้ย

# %%
pop_gar.isnull().any()
# Out:
# dcode           False
# dname           False
# population53    False
# population54    False
# population55    False
# population56    False
# population57    False
# population58    False
# population59    False
# population61    False
# garbage53       False
# garbage54       False
# garbage55       False
# garbage56       False
# garbage57       False
# garbage58       False
# garbage59       False
# garbage61       False
# dtype: bool

# %% [markdown]
# จากที่เช็คค่า Missing แล้ว ไม่มีค่า Missing เกิดขึ้นหลังจากรวมตารางแล้ว

# %% [markdown]
# ##**รวมตาราง population, garbage และ moveinmoveout**

# %%
pop_gar_moveinout = pd.merge(pop_gar, moveinmoveout_new,how='left', on='dcode')
pop_gar_moveinout
# Out:
#     dcode              dname  population53  ...  moveout58  moveout59  moveout61
# 0    1001             พระนคร         60313  ...       3589       3644      11239
# 1    1002              ดุสิต        111496  ...      11133      13091       4750
# 2    1003            หนองจอก        151292  ...       7611       7536       3373
# 3    1004             บางรัก         47053  ...       5948       5967       5174
# 4    1005             บางเขน        188164  ...      12299      13537       4890
# 5    1006            บางกะปิ        149606  ...       9549       9826       3503
# 6    1007            ปทุมวัน         57368  ...       9502       8863       8308
# 7    1008  ป้อมปราบศัตรูพ่าย         53526  ...       3615       3340       6252
# 8    1009            พระโขนง         95661  ...       4846       5796       6820
# 9    1010            มีนบุรี        135032  ...      12268      12231       8300
# 10   1011          ลาดกระบัง        157477  ...       9167       9343       7026
# ...

# %% [markdown]
# **dcode = PK ของตาราง คือเขตภายในกรุงเทพมหานคร**
#
# **dname = FK ของตาราง คือชื่อเขตภายในกรุงเทพมหานคร**
#
# **population53 = จำนวนประชากรคนกรุงเทพในปี 2553**
#
# **garbage53 = ปริมาณขยะของกรุงเทพในปี 2553**
#
# **movein = จำนวนคนที่ย้ายเข้ากรุงเทพในปี 2553**
#
# **moveout = จำนวนคนที่ย้ายออกจากกรุงเทพในปี 2553 เป็นต้น**

# %% [markdown]
# ### เช็คว่ามีค่า Missing มั้ย

# %%
pop_gar_moveinout.isnull().any()
# Out:
# dcode           False
# dname           False
# population53    False
# population54    False
# population55    False
# population56    False
# population57    False
# population58    False
# population59    False
# population61    False
# garbage53       False
# garbage54       False
# garbage55       False
# garbage56       False
# garbage57       False
# garbage58       False
# garbage59       False
# garbage61       False
# movein53        False
# movein54        False
# movein55        False
# movein56        False
# movein57        False
# movein58        False
# movein59        False
# movein61        False
# moveout53       False
# moveout54       False
# moveout55       False
# moveout56       False
# moveout57       False
# moveout58       False
# moveout59       False
# moveout61       False
# dtype: bool

# %% [markdown]
# จากที่เช็คค่า Missing แล้ว ไม่มีค่า Missing เกิดขึ้นหลังจากรวมตารางแล้ว

# %% [markdown]
# ### **Final Project**

# %% [markdown]
# ปัญหา (Classification ที่ต้องการเข้า) - ประโยชน์
#
# การเลือก model
#
# การวัดผล
#
# Visualization

# %% [markdown]
# **ตาราง จำนวนประชากรในแต่ละปี, ปริมาณขยะในแต่ละปี, จำนวนคนที่ย้ายเข้ามาในกรุงเทพในแต่ละปี และ จำนวนคนที่ย้ายออกจากกรุงเทพในแต่ละปี**

# %%
pop_gar_moveinout
# Out:
#     dcode              dname  population53  ...  moveout58  moveout59  moveout61
# 0    1001             พระนคร         60313  ...       3589       3644      11239
# 1    1002              ดุสิต        111496  ...      11133      13091       4750
# 2    1003            หนองจอก        151292  ...       7611       7536       3373
# 3    1004             บางรัก         47053  ...       5948       5967       5174
# 4    1005             บางเขน        188164  ...      12299      13537       4890
# 5    1006            บางกะปิ        149606  ...       9549       9826       3503
# 6    1007            ปทุมวัน         57368  ...       9502       8863       8308
# 7    1008  ป้อมปราบศัตรูพ่าย         53526  ...       3615       3340       6252
# 8    1009            พระโขนง         95661  ...       4846       5796       6820
# 9    1010            มีนบุรี        135032  ...      12268      12231       8300
# 10   1011          ลาดกระบัง        157477  ...       9167       9343       7026
# ...

# %% [markdown]
# ### **วัตถุประสงค์**

# %% [markdown]
# ทำนายว่าปริมาณขยะที่เพิ่มขึ้น ซึ่งมีผลมาจากจำนวนสวนสาธาณะ, จำนวนประชากร, จำนวนการย้ายเข้า และ จำนวนการย้ายออก ในเขตกรุงเทพมหานคร

# %% [markdown]
# ### **ประโยชน์**

# %% [markdown]
# ปัจจัยที่ส่งผลการเพิ่มขึ้น-ลดลงของขยะ ได้แก่จำนวนประชากร,การย้ายเข้า-ออก และ จำนวนสวนสาธารณะในเขตกรุงเทพมหานคร

# %% [markdown]
# **ข้อมูลเพิ่มเติม**

# %%
import pandas as pd #ทำงานกับข้อมูลลักษณะตาราง

# %%
from google.colab import drive #เชื่อมเข้ากับ Drive 
drive.mount('/content/drive') # คลิกที่ลิงก์ -> เลือก E-mail -> ลงชื่อเข้าใช้ -> ก็อปโค้ด -> นำกลับมาวางในช่องว่าง -> กด enter
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os  # os เอาไว้จัดการไฟล์และ path

# %%
path = '/content/drive/My Drive/DWDM2021_DATA'

# %%
park = pd.read_csv(os.path.join(path, 'park.csv')) #เพิ่มข้อมูลจำนวนสวนสาธารณะเข้ามา

# %%
park
# Out:
#     dcode  num_park54  num_park55  ...  ratio60  ratio61  ratio62
# 0    1001          89          95  ...        0        0       12
# 1    1002         100         103  ...        0        0       12
# 2    1003         176         186  ...        0        0        8
# 3    1004         144         168  ...        0        0        3
# 4    1005          43          44  ...        0        0        5
# 5    1006         119         121  ...        0        0        5
# 6    1007          96          99  ...        0        0       18
# 7    1008         131         133  ...        0        0        6
# 8    1009         299         309  ...        0        0        3
# 9    1010         123         142  ...        0        0        5
# 10   1011          94          99  ...        0        0        3
# 11   1012         154         185  ...        0        0        7
# 12   1013         118         126  ...        0        0        6
# ...

# %% [markdown]
# ### **เลือกมาเฉพาะจำนวนสวนสาธารณะของปี 59**

# %%
park59 = park.iloc[:,[0,6]]

# %% [markdown]
# **เลือกแค่ปีที่สนใจคือปี 2559**

# %%
park59
# Out:
#     dcode  num_park59
# 0    1001         111
# 1    1002         115
# 2    1003         178
# 3    1004         243
# 4    1005          72
# 5    1006         157
# 6    1007         122
# 7    1008         112
# 8    1009         332
# 9    1010         226
# 10   1011         114
# 11   1012         215
# 12   1013          97
# 13   1014          71
# 14   1015         126
# 15   1016         100
# 16   1017         107
# 17   1018         131
# 18   1019         199
# 19   1020         162
# 20   1021         289
# 21   1022         119
# 22   1023         187
# 23   1024         158
# 24   1025         110
# 25   1026         135
# 26   1027         128
# 27   1028          97
# 28   1029         147
# 29   1030         124
# 30   1031         139
# 31   1032          84
# 32   1033         115
# 33   1034         125
# 34   1035         144
# 35   1036          58
# 36   1037         163
# 37   1038         116
# 38   1039         130
# 39   1040         288
# ...

# %%
park59.isnull().any()   #.isnull เพื่อดูค่า missing เเละพบว่าไม่มีค่า missing
# Out:
# dcode         False
# num_park59    False
# dtype: bool

# %%
data2 = pd.merge(pop_gar_moveinout, park59,how='left', on='dcode')
data2  
#เชื่อมตารางข้อมูล pop_gar_moveinout กับตาราง park59
# Out:
#     dcode              dname  population53  ...  moveout59  moveout61  num_park59
# 0    1001             พระนคร         60313  ...       3644      11239         111
# 1    1002              ดุสิต        111496  ...      13091       4750         115
# 2    1003            หนองจอก        151292  ...       7536       3373         178
# 3    1004             บางรัก         47053  ...       5967       5174         243
# 4    1005             บางเขน        188164  ...      13537       4890          72
# 5    1006            บางกะปิ        149606  ...       9826       3503         157
# 6    1007            ปทุมวัน         57368  ...       8863       8308         122
# 7    1008  ป้อมปราบศัตรูพ่าย         53526  ...       3340       6252         112
# 8    1009            พระโขนง         95661  ...       5796       6820         332
# 9    1010            มีนบุรี        135032  ...      12231       8300         226
# ...

# %%
data59_2 = data2[['dcode','dname','population59','garbage59','movein59','moveout59','num_park59']]
data59_2

#เลือกเฉพาะcolumn ที่เป็นปี 59
# Out:
#     dcode              dname  population59  ...  movein59  moveout59  num_park59
# 0    1001             พระนคร         52522  ...      2815       3644         111
# 1    1002              ดุสิต         98450  ...      9438      13091         115
# 2    1003            หนองจอก        167844  ...     10747       7536         178
# 3    1004             บางรัก         47308  ...      1656       5967         243
# 4    1005             บางเขน        190828  ...     14337      13537          72
# 5    1006            บางกะปิ        148392  ...      9016       9826         157
# 6    1007            ปทุมวัน         49594  ...      2016       8863         122
# 7    1008  ป้อมปราบศัตรูพ่าย         47450  ...      1200       3340         112
# 8    1009            พระโขนง         91305  ...      5586       5796         332
# 9    1010            มีนบุรี        141214  ...      8763      12231         226
# 10   1011          ลาดกระบัง        171933  ...     11843       9343         114
# ...

# %%
data59_2.isnull().any() #หาค่าmissing ปรากฏว่าไม่มีค่า missing เลย
# Out:
# dcode           False
# dname           False
# population59    False
# garbage59       False
# movein59        False
# moveout59       False
# num_park59      False
# dtype: bool

# %% [markdown]
# **เพิ่ม coloumn AmountofGarbage**
#
# **แบ่งปริมาณขยะ ในคอลัมน์ garbage59 เป็น**
#
# **ปริมาณขยะน้อยมีค่า 0 - 50,000**
#
# **ปริมาณขยะปานกลางมีค่า ระหว่าง 50,000 - 70,000**
#
# **ปริมาณขยะมากมีค่า 70,000 - 150,000**

# %%
from pandas.api.types import CategoricalDtype

# %%
Amount2  = ['low','median','high']
data59_2['Amount0fGarbage'] = pd.cut(data59_2.garbage59,
                            bins=[0,50000,100000,150000],
                            labels=Amount2,
                            right=False).astype(str).astype(CategoricalDtype(Amount2,ordered=True))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
data59_2
# Out:
#     dcode              dname  ...  num_park59  Amount0fGarbage
# 0    1001             พระนคร  ...         111           median
# 1    1002              ดุสิต  ...         115           median
# 2    1003            หนองจอก  ...         178              low
# 3    1004             บางรัก  ...         243           median
# 4    1005             บางเขน  ...          72             high
# 5    1006            บางกะปิ  ...         157             high
# 6    1007            ปทุมวัน  ...         122              low
# 7    1008  ป้อมปราบศัตรูพ่าย  ...         112             high
# 8    1009            พระโขนง  ...         332           median
# 9    1010            มีนบุรี  ...         226           median
# 10   1011          ลาดกระบัง  ...         114           median
# 11   1012            ยานนาวา  ...         215           median
# 12   1013        สัมพันธวงศ์  ...          97              low
# 13   1014              พญาไท  ...          71           median
# ...

# %%
data59_2['Amount0fGarbage'] = data59_2['Amount0fGarbage'].map({'low':1,'median':2,'high':3})
data59_2
#.map ทำการเปลี่ยน low median high เป็นตัวเลข 1,2 และ 3 ตามลำดับ
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     dcode              dname  ...  num_park59  Amount0fGarbage
# 0    1001             พระนคร  ...         111                2
# 1    1002              ดุสิต  ...         115                2
# 2    1003            หนองจอก  ...         178                1
# 3    1004             บางรัก  ...         243                2
# 4    1005             บางเขน  ...          72                3
# 5    1006            บางกะปิ  ...         157                3
# 6    1007            ปทุมวัน  ...         122                1
# 7    1008  ป้อมปราบศัตรูพ่าย  ...         112                3
# ...

# %%
X1 = data59_2[['num_park59','population59', 'movein59', 'moveout59']]
X1
#กำหนดค่าX คือ จำนวนสวนสาธารณะปี59 จำนวนประชากรปี59 และการย้ายเข้า-ออกปี59
# Out:
#     num_park59  population59  movein59  moveout59
# 0          111         52522      2815       3644
# 1          115         98450      9438      13091
# 2          178        167844     10747       7536
# 3          243         47308      1656       5967
# 4           72        190828     14337      13537
# 5          157        148392      9016       9826
# 6          122         49594      2016       8863
# 7          112         47450      1200       3340
# 8          332         91305      5586       5796
# 9          226        141214      8763      12231
# 10         114        171933     11843       9343
# 11         215         79574      4083       4188
# 12          97         24785       673       1268
# 13          71         72102      6717       8460
# 14         126        111027      4521       7901
# 15         100         67887      2486       3366
# 16         107         81190      6049       6943
# 17         131         73871      2959       5304
# ...

# %%
X1.dtypes
# Out:
# num_park59      int64
# population59    int64
# movein59        int64
# moveout59       int64
# dtype: object

# %%
X = X1.replace('[^\d.]','', regex=True).astype(float) 
#แทนค่าในตารางจาก int ให้เป็น float ทั้งหมด

# %%
X
# Out:
#     num_park59  population59  movein59  moveout59
# 0        111.0       52522.0    2815.0     3644.0
# 1        115.0       98450.0    9438.0    13091.0
# 2        178.0      167844.0   10747.0     7536.0
# 3        243.0       47308.0    1656.0     5967.0
# 4         72.0      190828.0   14337.0    13537.0
# 5        157.0      148392.0    9016.0     9826.0
# 6        122.0       49594.0    2016.0     8863.0
# 7        112.0       47450.0    1200.0     3340.0
# 8        332.0       91305.0    5586.0     5796.0
# 9        226.0      141214.0    8763.0    12231.0
# 10       114.0      171933.0   11843.0     9343.0
# 11       215.0       79574.0    4083.0     4188.0
# 12        97.0       24785.0     673.0     1268.0
# 13        71.0       72102.0    6717.0     8460.0
# 14       126.0      111027.0    4521.0     7901.0
# 15       100.0       67887.0    2486.0     3366.0
# 16       107.0       81190.0    6049.0     6943.0
# 17       131.0       73871.0    2959.0     5304.0
# ...

# %%
y1 = data59_2[['Amount0fGarbage']]
y1  #ค่า y เป็นคำตอบได้ดังนี้
# Out:
#    Amount0fGarbage
# 0                2
# 1                2
# 2                1
# 3                2
# 4                3
# 5                3
# 6                1
# 7                3
# 8                2
# 9                2
# 10               2
# 11               2
# 12               1
# 13               2
# 14               2
# 15               1
# 16               2
# 17               1
# 18               1
# 19               2
# 20               3
# 21               2
# 22               2
# 23               1
# 24               2
# 25               2
# 26               2
# 27               2
# 28               2
# 29               3
# 30               2
# 31               2
# 32               3
# 33               2
# 34               2
# 35               2
# 36               2
# 37               2
# 38               3
# 39               2
# 40               2
# 41               2
# 42               2
# 43               1
# 44               2
# 45               2
# ...

# %%
y1.shape
# Out:
# (50, 1)

# %%
y2 = data59_2['Amount0fGarbage']
y2
# Out:
# 0     2
# 1     2
# 2     1
# 3     2
# 4     3
# 5     3
# 6     1
# 7     3
# 8     2
# 9     2
# 10    2
# 11    2
# 12    1
# 13    2
# 14    2
# 15    1
# 16    2
# 17    1
# 18    1
# 19    2
# 20    3
# 21    2
# 22    2
# 23    1
# 24    2
# 25    2
# 26    2
# 27    2
# 28    2
# 29    3
# 30    2
# 31    2
# 32    3
# 33    2
# 34    2
# 35    2
# 36    2
# 37    2
# 38    3
# 39    2
# 40    2
# 41    2
# 42    2
# 43    1
# 44    2
# 45    2
# 46    2
# 47    1
# 48    1
# 49    2
# Name: Amount0fGarbage, dtype: category
# Categories (3, int64): [1 < 2 < 3]

# %%
y = y2.values
y
# Out:
# [2, 2, 1, 2, 3, ..., 2, 2, 1, 1, 2]
# Length: 50
# Categories (3, int64): [1 < 2 < 3]

# %%
y.shape
# Out:
# (50,)

# %% [markdown]
# ## **Classification**

# %% [markdown]
# ### **Decision Tree**

# %%
from sklearn.model_selection import train_test_split
 #import เรียกข้อมูล

# %% [markdown]
# **Train - Test**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=6)

# %%
X_train.shape #ขนาดข้อมูล
# Out:
# (25, 4)

# %% [markdown]
# **Train - Validation**

# %%
X_train2, X_val, y_train2, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=6)

# %%
X_train2.shape
# Out:
# (17, 4)

# %% [markdown]
# **import**

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **define**

# %%
Definemytree = DecisionTreeClassifier(random_state=6) #มูล กำหนดrandom เท่ากับ 6

# %% [markdown]
# **train**

# %%
mytree.fit(X_train2,y_train2) #สร้างโมเดลของข้อมูล
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=6, splitter='best')

# %% [markdown]
# **Evaluate**

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Test**

# %%
mytree_result = mytree.predict(X_val)

# %%
DecisionTree = accuracy_score(y_val,mytree_result)
DecisionTree

#ค่าความเเม่นยำ เท่ากับ 75%
# Out:
# 0.75

# %% [markdown]
# **plot tree**

# %%
from sklearn.tree import plot_tree #import ข้อมูล

# %%
plot_tree(mytree) # plot แผนภาพต้นไม้
# Out:
# [Text(148.8, 195.696, 'X[3] <= 3777.0\ngini = 0.381\nsamples = 17\nvalue = [1, 13, 3]'),
#  Text(111.60000000000001, 152.208, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(186.0, 152.208, 'X[1] <= 175850.5\ngini = 0.305\nsamples = 16\nvalue = [0, 13, 3]'),
#  Text(111.60000000000001, 108.72, 'X[3] <= 6669.0\ngini = 0.142\nsamples = 13\nvalue = [0, 12, 1]'),
#  Text(74.4, 65.232, 'X[3] <= 6273.5\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(37.2, 21.744, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(111.60000000000001, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(148.8, 65.232, 'gini = 0.0\nsamples = 9\nvalue = [0, 9, 0]'),
#  Text(260.40000000000003, 108.72, 'X[2] <= 15039.5\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(223.20000000000002, 65.232, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(297.6, 65.232, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]')]

# %% [markdown]
# root node คือ x[3] <= 3777.0
#
# information grain = 0.381 ค่ามากสุดเป็น root node
#
# มี data ไหลเข้ามา 17 ตัว
#
# เเบ่งเป็น 3 กลุ่ม คือ 1 , 13 , 3

# %% [markdown]
# ### **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier #import ข้อมูล

# %% [markdown]
# **KNN1**

# %%
# Define
neigh1 = KNeighborsClassifier(n_neighbors=3, weights='uniform') #ถามเพื่อนบ้านที่ใกล้สุด 3 คน และเชื่อทุกๆคนเท่ากัน
# Train
neigh1.fit(X_train2,y_train2)
# Test
knn1_result = neigh1.predict(X_val)
accuracy_score(y_val, knn1_result)
# Out:
# 0.625

# %% [markdown]
# **KNN2**

# %%
# Define
neigh2 = KNeighborsClassifier(n_neighbors=7, weights='distance') #ถามเพื่อนบ้านที่ใกล้สุด 7 คน และเชื่อคนที่อยู่ใกล้มากกว่าคนที่อยู่ไกล
# Train
neigh2.fit(X_train2,y_train2)
# Test
knn2_result = neigh2.predict(X_val)
accuracy_score(y_val, knn2_result)
# Out:
# 0.625

# %% [markdown]
# **KNN3**

# %%
# Define
neigh3 = KNeighborsClassifier(n_neighbors=1) #เชื่อเพื่อนบ้านที่ใกล้ที่สุดคนเดียว
# Train
neigh3.fit(X_train2,y_train2)
# Test
knn3_result = neigh3.predict(X_val)
accuracy_score(y_val, knn3_result)
# Out:
# 0.75

# %% [markdown]
# #### **Retrain & Evaluate**

# %%
#Define
neigh3_final = KNeighborsClassifier(n_neighbors=1)
#Train
neigh3_final.fit(X_train,y_train)
#test
knn3_final_result = neigh3_final.predict(X_test)

# %%
KNN = accuracy_score(y_test, knn3_final_result)
KNN
# Out:
# 0.36

# %% [markdown]
# ### **Neural Network**

# %%
from sklearn.neural_network import MLPClassifier

# %%
perceptron1 = MLPClassifier(random_state=6, max_iter=2000, hidden_layer_sizes=1,learning_rate_init=0.005)

# %% [markdown]
# **Train - Test**

# %% [markdown]
# **ANN1**

# %%
# Train
perceptron1.fit(X_train2,y_train2)
# Test
ann1_result = perceptron1.predict(X_val)
accuracy_score(y_val, ann1_result)
# Out:
# 0.625

# %% [markdown]
# **ANN 2**

# %%
perceptron2 = MLPClassifier(random_state=6, max_iter=2000, hidden_layer_sizes=10,learning_rate_init=0.005)
# Train
perceptron2.fit(X_train2,y_train2)
# Test
ann2_result = perceptron2.predict(X_val)
accuracy_score(y_val, ann2_result)
# Out:
# 0.75

# %% [markdown]
# **ANN 3**

# %%
perceptron3 = MLPClassifier(random_state=6, max_iter=20000, hidden_layer_sizes=10,learning_rate_init=0.001)
# Train
perceptron3.fit(X_train2,y_train2)
# Test
ann3_result = perceptron3.predict(X_val)
accuracy_score(y_val, ann3_result)
# Out:
# 0.625

# %% [markdown]
# #### **Retrain & Evaluate**

# %%
perceptron2_final = MLPClassifier(random_state=6, max_iter=2000,hidden_layer_sizes=10,learning_rate_init=0.005)
#Train
perceptron2_final.fit(X_train,y_train)
#Test
perceptron2final_result = perceptron2_final.predict(X_test)

# %%
Neural = accuracy_score(y_test,perceptron2final_result)
Neural
# Out:
# 0.6

# %% [markdown]
# **จาก Model ทั้ง 3 ชนิด พบว่า Model ที่มีความแม่นยำมากที่สุด คือ DesisionTree มีความแม่นยำ 75%**

# %% [markdown]
# ### เลือก Model ทำนาย

# %% [markdown]
# **Import**

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Define**

# %%
mytree = DecisionTreeClassifier(random_state=6)
#defineข้อมูล โดยกำหนดramdom เท่ากับ 6

# %% [markdown]
# **Train**

# %%
mytree.fit(X_train2,y_train2) #สร้างโมเดลของข้อมูล
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=6, splitter='best')

# %% [markdown]
# **Evaluation**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
accuracy_score(y_val,mytree_result)

#ความเเม่นยำเท่ากับ 75%
# Out:
# 0.75

# %%
confusion_matrix(y_val, mytree_result)
# Out:
# array([[1, 1, 0],
#        [0, 5, 0],
#        [0, 1, 0]])

# %%
ret = classification_report(y_val, mytree_result)
print(ret)

#1 precision 100%  recall 50%  f1-score 67%  support(จำนวนข้อมูลที่เป็น1) 2 ตัว
#2 precision 71%  recall 100%  f1-score 83%  support(จำนวนข้อมูลที่เป็น2) 5 ตัว
#3 precision 0%  recall  0%  f1-score 0%  support(จำนวนข้อมูลที่เป็น3) 1 ตัว
#ความแม่นยำ 75%
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.50      0.67         2
#            2       0.71      1.00      0.83         5
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.75         8
#    macro avg       0.57      0.50      0.50         8
# weighted avg       0.70      0.75      0.69         8
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## **Visualization**

# %% [markdown]
# **เปรียบเทียบความแม่นยำ ของการทำ Classification ด้วย accuracy_score**

# %%
from matplotlib import pyplot as plt

labels = ['Decision Tree', 'KNN', 'Neural Network']
accuracy_Y = [DecisionTree,KNN,Neural]
#plot
plt.bar(labels,accuracy_Y)
plt.ylabel('Accuracy Score')
plt.title('Compare Acuuracy_score')
plt.legend();
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **ติดตั้งฟ้อนภาษาไทย**

# %%
plt.rcParams['font.family'] = 'Tahoma'

# %%
data59_2
# Out:
#     dcode              dname  ...  num_park59  Amount0fGarbage
# 0    1001             พระนคร  ...         111                2
# 1    1002              ดุสิต  ...         115                2
# 2    1003            หนองจอก  ...         178                1
# 3    1004             บางรัก  ...         243                2
# 4    1005             บางเขน  ...          72                3
# 5    1006            บางกะปิ  ...         157                3
# 6    1007            ปทุมวัน  ...         122                1
# 7    1008  ป้อมปราบศัตรูพ่าย  ...         112                3
# 8    1009            พระโขนง  ...         332                2
# 9    1010            มีนบุรี  ...         226                2
# 10   1011          ลาดกระบัง  ...         114                2
# 11   1012            ยานนาวา  ...         215                2
# 12   1013        สัมพันธวงศ์  ...          97                1
# 13   1014              พญาไท  ...          71                2
# ...

# %%
population_gar_low = data59_2[data59_2['garbage59'] < 50000]
population_gar_low
#ตารางข้อมูลจำนวนประชากรกับปริมาณขยะที่น้อยกว่า 50,000
# Out:
#     dcode        dname  population59  ...  moveout59  num_park59  Amount0fGarbage
# 2    1003      หนองจอก        167844  ...       7536         178                1
# 6    1007      ปทุมวัน         49594  ...       8863         122                1
# 12   1013  สัมพันธวงศ์         24785  ...       1268          97                1
# 15   1016   บางกอกใหญ่         67887  ...       3366         100                1
# 17   1018      คลองสาน         73871  ...       5304         131                1
# 18   1019     ตลิ่งชัน        105289  ...       4413         199                1
# 23   1024  ราษฎร์บูรณะ         83248  ...       5561         158                1
# 43   1044     สะพานสูง         94982  ...       4783         129                1
# 47   1048     ทวีวัฒนา         77890  ...       3619         102                1
# 48   1049      ทุ่งครุ        120976  ...       6083         202                1
#
# [10 rows x 8 columns]

# %%
graph1 = population_gar_low.describe()

# %%
graph1
# Out:
#              dcode   population59  ...    moveout59  num_park59
# count    10.000000      10.000000  ...    10.000000   10.000000
# mean   1024.100000   86636.600000  ...  5079.600000  141.800000
# std      16.921059   39428.785644  ...  2154.254921   40.110403
# min    1003.000000   24785.000000  ...  1268.000000   97.000000
# 25%    1013.750000   69383.000000  ...  3817.500000  107.000000
# 50%    1018.500000   80569.000000  ...  5043.500000  130.000000
# 75%    1039.000000  102712.250000  ...  5952.500000  173.000000
# max    1049.000000  167844.000000  ...  8863.000000  202.000000
#
# [8 rows x 6 columns]

# %%
import numpy as np  #import ข้อมูล

# %%
labels = ['population1']
pop_low_mean = [86636.6]
gar_loe_mean = [38770.3]

# %%
width = 0.35

plt.bar(np.array([1]) - width/2, pop_low_mean, width=width, label = 'population')
plt.bar(np.array([1]) + width/2, gar_loe_mean, width=width, label = 'garbage')
plt.legend()

plt.ylabel('Quatity')
plt.title('Compare mean between population and garbage (low)')
# Out:
# Text(0.5, 1.0, 'Compare mean between population and garbage (low)')

# %%
width =0.35

plt.bar(np.arange(len(population_gar_low.iloc[:,[1,2,3]])) - width/2, population_gar_low.iloc[:,2], width=width, label = 'Population')
plt.bar(np.arange(len(population_gar_low.iloc[:,[1,2,3]])) + width/2, population_gar_low.iloc[:,3], width=width, label = 'Garbage')

plt.ylabel('Quantity')
plt.title('Compare Population vs Garbage')
plt.xticks(np.arange(len(population_gar_low.iloc[:,[1,2,3]])),population_gar_low.iloc[:,1], rotation=-45) #rotation คือตัวหมุนวันที่ตรงแกน x มห้มันเป็นแนวตั้ง
plt.legend();
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3627 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3591 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
population_gar_median = data59_2[data59_2['Amount0fGarbage'] == 2]

# %%
population_gar_median
# Out:
#     dcode       dname  population59  ...  moveout59  num_park59  Amount0fGarbage
# 0    1001      พระนคร         52522  ...       3644         111                2
# 1    1002       ดุสิต         98450  ...      13091         115                2
# 3    1004      บางรัก         47308  ...       5967         243                2
# 8    1009     พระโขนง         91305  ...       5796         332                2
# 9    1010     มีนบุรี        141214  ...      12231         226                2
# 10   1011   ลาดกระบัง        171933  ...       9343         114                2
# 11   1012     ยานนาวา         79574  ...       4188         215                2
# 13   1014       พญาไท         72102  ...       8460          71                2
# 14   1015      ธนบุรี        111027  ...       7901         126                2
# 16   1017    ห้วยขวาง         81190  ...       6943         107                2
# 19   1020  บางกอกน้อย        112581  ...      14251         162                2
# ...

# %%
graph2 = population_gar_median.describe() #เอาตารางมาอธิบายข้อมูลได้ดังนี้

# %%
graph2
# Out:
#              dcode   population59  ...     moveout59  num_park59
# count    33.000000      33.000000  ...     33.000000   33.000000
# mean   1027.030303  118393.121212  ...   8612.212121  154.484848
# std      14.090078   40216.603593  ...   3078.458743   60.901109
# min    1001.000000   47308.000000  ...   3644.000000   58.000000
# 25%    1015.000000   91305.000000  ...   6296.000000  114.000000
# 50%    1028.000000  112581.000000  ...   8055.000000  139.000000
# 75%    1038.000000  144449.000000  ...   9836.000000  181.000000
# max    1050.000000  200374.000000  ...  15478.000000  332.000000
#
# [8 rows x 6 columns]

# %%
labels = ['population2']
pop_median_mean = [118393.1]
gar_median_mean = [70118.9]
#เลือกค่าmean มาplotกราฟ

# %%
width = 0.35 

plt.bar(np.array([1]) - width/2, pop_median_mean, width=width, label = 'population')
plt.bar(np.array([1]) + width/2, gar_median_mean, width=width, label = 'garbage')
plt.legend()

plt.ylabel('Quatity')
plt.title('Compare mean between population and garbage (median)')
# Out:
# Text(0.5, 1.0, 'Compare mean between population and garbage (median)')

# %%
width =0.35

plt.bar(np.arange(len(population_gar_median.iloc[:,[1,2,3]])) - width/2, population_gar_median.iloc[:,2], width=width, label = 'Population')
plt.bar(np.arange(len(population_gar_median.iloc[:,[1,2,3]])) + width/2, population_gar_median.iloc[:,3], width=width, label = 'Garbage')

plt.ylabel('Quantity')
plt.title('Compare Population vs Garbage')
plt.xticks(np.arange(len(population_gar_median.iloc[:,[1,2,3]])),population_gar_median.iloc[:,1], rotation=-45) #rotation คือตัวหมุนวันที่ตรงแกน x มห้มันเป็นแนวตั้ง
plt.legend();
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3614 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3632 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
population_gar_high = data59_2[data59_2['Amount0fGarbage'] == 3]

# %%
population_gar_high
# Out:
#     dcode              dname  ...  num_park59  Amount0fGarbage
# 4    1005             บางเขน  ...          72                3
# 5    1006            บางกะปิ  ...         157                3
# 7    1008  ป้อมปราบศัตรูพ่าย  ...         112                3
# 20   1021        บางขุนเทียน  ...         289                3
# 29   1030            จตุจักร  ...         124                3
# 32   1033            คลองเตย  ...         115                3
# 38   1039              วัฒนา  ...         130                3
#
# [7 rows x 8 columns]

# %%
graph3 = population_gar_high.describe()

# %%
graph3
# Out:
#              dcode   population59  ...     moveout59  num_park59
# count     7.000000       7.000000  ...      7.000000    7.000000
# mean   1020.285714  130472.428571  ...   8470.285714  142.714286
# std      14.115173   52997.134287  ...   3527.504440   69.315016
# min    1005.000000   47450.000000  ...   3340.000000   72.000000
# 25%    1007.000000   94369.500000  ...   5915.500000  113.500000
# 50%    1021.000000  148392.000000  ...   9826.000000  124.000000
# 75%    1031.500000  168949.000000  ...  10379.000000  143.500000
# max    1039.000000  190828.000000  ...  13537.000000  289.000000
#
# [8 rows x 6 columns]

# %%
labels = ['population3']
pop_high_mean = [130472.4]
gar_high_mean = [115215.3]

# %%
width = 0.35

plt.bar(np.array([1]) - width/2, pop_high_mean, width=width, label = 'population')
plt.bar(np.array([1]) + width/2, gar_high_mean, width=width, label = 'garbage')
plt.legend()

plt.ylabel('Quatity')
plt.title('Compare mean between population and garbage (high)')
# Out:
# Text(0.5, 1.0, 'Compare mean between population and garbage (high)')

# %%
width =0.35

plt.bar(np.arange(len(population_gar_high.iloc[:,[1,2,3]])) - width/2, population_gar_high.iloc[:,2], width=width, label = 'Population')
plt.bar(np.arange(len(population_gar_high.iloc[:,[1,2,3]])) + width/2, population_gar_high.iloc[:,3], width=width, label = 'Garbage')

plt.ylabel('Quantity')
plt.title('Compare Population vs Garbage')
plt.xticks(np.arange(len(population_gar_high.iloc[:,[1,2,3]])),population_gar_high.iloc[:,1], rotation=-45) #rotation คือตัวหมุนวันที่ตรงแกน x มห้มันเป็นแนวตั้ง
plt.legend();
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3610 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3591 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3586 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
labels = ['1,2,3']
pop_mean_final = [86636.6,118393.1,130472.4]
gar_mean_final = [38770.3,70118.9,115215.3]

#เอาข้อมูลทั้งสามอันมา plot กราฟ

# %%
width = 0.4

plt.bar(np.array([1,2,3]) - width/2, pop_mean_final, width=width, label = 'population')
plt.bar(np.array([1,2,3]) + width/2, gar_mean_final, width=width, label = 'garbage')
plt.legend()

plt.ylabel('Quatity')
plt.title('Compare mean between population and garbage')
# Out:
# Text(0.5, 1.0, 'Compare mean between population and garbage')
